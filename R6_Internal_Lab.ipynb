# %% [markdown]
# ## Linear Classifier in TensorFlow
# Using Low Level API in Eager Execution mode

# %% [markdown]
# ### Load tensorflow

# %%
# !pip3 install -U tensorflow --quiet
# Out:
#      |████████████████████████████████| 86.3MB 113kB/s
#      |████████████████████████████████| 450kB 44.8MB/s
#      |████████████████████████████████| 3.8MB 44.2MB/s
#      |████████████████████████████████| 81kB 8.5MB/s
# ERROR: tensorboard 2.0.1 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.6.3 which is incompatible.

# %%
import tensorflow as tf

# %%
#tf.set_random_seed(42)

# %%
#Enable Eager Execution if using tensflow version < 2.0
#From tensorflow v2.0 onwards, Eager Execution will be enabled by default

# %% [markdown]
# ### Collect Data

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
data1=pd.read_csv('/content/drive/My Drive/Colab Notebooks/prices.csv')

# %% [markdown]
# ### Check all columns in the dataset

# %%
data1.columns
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %% [markdown]
# ### Drop columns `date` and  `symbol`

# %%
data1.drop(columns=['date','symbol'],inplace=True)

# %%
data1.columns
# Out:
# Index(['open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
data1.head()
# Out:
#          open       close         low        high     volume
# 0  123.430000  125.839996  122.309998  126.250000  2163600.0
# 1  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2  116.379997  114.949997  114.930000  119.739998  2489500.0
# 3  115.480003  116.620003  113.500000  117.440002  2006300.0
# 4  117.010002  114.970001  114.089996  117.330002  1408600.0

# %%
data1.shape
# Out:
# (851264, 5)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 5 columns):
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5)
# memory usage: 32.5 MB

# %% [markdown]
# ### Consider only first 1000 rows in the dataset for building feature set and target set
# Target 'Volume' has very high values. Divide 'Volume' by 1000,000

# %%
data=data1.head(1000)

# %%
import numpy as np

# %%
data['volume'] = [np.divide(x,1000000) for x in data['volume']]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Divide the data into train and test sets

# %%
from sklearn.model_selection import train_test_split

# %%
X= np.array(data.drop(columns='volume'))
y= np.array(data['volume'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %% [markdown]
# #### Convert Training and Test Data to numpy float32 arrays

# %% [markdown]
# ### Normalize the data
# You can use Normalizer from sklearn.preprocessing

# %%
from sklearn.preprocessing import Normalizer

# %%
scale = Normalizer()

# %%
X_train_z = scale.fit_transform(X_train)

# %%
X_test_z= scale.fit_transform(X_test)

# %%
X_train_z.shape
# Out:
# (800, 4)

# %%
X_train_z = X_train_z.astype('float32')
X_test_z = X_test_z.astype('float32')
y_test = y_test.astype('float32')
y_train = y_train.astype('float32')

# %% [markdown]
# ## Building the Model in tensorflow

# %% [markdown]
# 1.Define Weights and Bias, use tf.zeros to initialize weights and Bias

# %%
#We are initializing weights and Bias with Zero
w = tf.zeros(shape=(4,1))
b = tf.zeros(shape=(1))

# %% [markdown]
# 2.Define a function to calculate prediction

# %%
def prediction(x, w, b):
    
    xw_matmul = tf.matmul(x, w)
    y = tf.add(xw_matmul, b)
    
    return y

# %% [markdown]
# 3.Loss (Cost) Function [Mean square error]

# %%
def loss(y_actual, y_predicted):
    
    diff = y_actual - y_predicted
    sqr = tf.square(diff)
    avg = tf.reduce_mean(sqr)
    
    return avg

# %% [markdown]
# 4.Function to train the Model
#
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(x, y_actual, w, b, learning_rate=0.01):
    
    #Record mathematical operations on 'tape' to calculate loss
    with tf.GradientTape() as t:
        
        t.watch([w,b])
        
        current_prediction = prediction(x, w, b)
        current_loss = loss(y_actual, current_prediction)
    
    #Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    
    #Update Weights and Bias
    w = w - learning_rate*dw
    b = b - learning_rate*db
    
    return w, b

# %% [markdown]
# ## Train the model for 100 epochs
# 1. Observe the training loss at every iteration
# 2. Observe Train loss at every 5th iteration

# %%
for i in range(100):
    
    w, b = train(X_train_z, y_train, w, b)
    print('Current Loss on iteration', i, loss(y_train, prediction(X_train_z, w, b)).numpy())
# Out:
# Current Loss on iteration 0 195.3701
# Current Loss on iteration 1 193.45137
# Current Loss on iteration 2 191.68303
# Current Loss on iteration 3 190.05319
# Current Loss on iteration 4 188.5513
# Current Loss on iteration 5 187.16687
# Current Loss on iteration 6 185.89122
# Current Loss on iteration 7 184.71547
# Current Loss on iteration 8 183.632
# Current Loss on iteration 9 182.63333
# Current Loss on iteration 10 181.7131
# Current Loss on iteration 11 180.8649
# Current Loss on iteration 12 180.08328
# Current Loss on iteration 13 179.36282
# Current Loss on iteration 14 178.69897
# Current Loss on iteration 15 178.08717
# Current Loss on iteration 16 177.52328
# Current Loss on iteration 17 177.00352
# Current Loss on iteration 18 176.52455
# Current Loss on iteration 19 176.0832
# Current Loss on iteration 20 175.67647
# Current Loss on iteration 21 175.30157
# Current Loss on iteration 22 174.95602
# Current Loss on iteration 23 174.6377
# Current Loss on iteration 24 174.34407
# Current Loss on iteration 25 174.07378
# Current Loss on iteration 26 173.8245
# Current Loss on iteration 27 173.5948
# Current Loss on iteration 28 173.38312
# Current Loss on iteration 29 173.18793
# Current Loss on iteration 30 173.00815
# Current Loss on iteration 31 172.84247
# Current Loss on iteration 32 172.68974
# Current Loss on iteration 33 172.549
# Current Loss on iteration 34 172.4193
# Current Loss on iteration 35 172.2998
# Current Loss on iteration 36 172.1896
# Current Loss on iteration 37 172.0881
# Current Loss on iteration 38 171.99457
# Current Loss on iteration 39 171.9083
# Current Loss on iteration 40 171.82872
# Current Loss on iteration 41 171.75557
# Current Loss on iteration 42 171.6881
# Current Loss on iteration 43 171.62581
# Current Loss on iteration 44 171.56848
# Current Loss on iteration 45 171.51573
# Current Loss on iteration 46 171.4669
# Current Loss on iteration 47 171.42204
# Current Loss on iteration 48 171.3807
# Current Loss on iteration 49 171.34262
# Current Loss on iteration 50 171.30753
# Current Loss on iteration 51 171.27513
# Current Loss on iteration 52 171.24525
# Current Loss on iteration 53 171.21777
# Current Loss on iteration 54 171.1924
# Current Loss on iteration 55 171.16913
# Current Loss on iteration 56 171.14752
# Current Loss on iteration 57 171.12767
# Current Loss on iteration 58 171.1094
# Current Loss on iteration 59 171.09262
# Current Loss on iteration 60 171.07706
# Current Loss on iteration 61 171.06279
# Current Loss on iteration 62 171.0496
# Current Loss on iteration 63 171.03745
# Current Loss on iteration 64 171.02623
# Current Loss on iteration 65 171.0158
# Current Loss on iteration 66 171.00632
# Current Loss on iteration 67 170.9977
# Current Loss on iteration 68 170.98955
# Current Loss on iteration 69 170.98206
# Current Loss on iteration 70 170.97522
# Current Loss on iteration 71 170.96886
# Current Loss on iteration 72 170.9631
# Current Loss on iteration 73 170.95767
# Current Loss on iteration 74 170.9527
# Current Loss on iteration 75 170.94817
# Current Loss on iteration 76 170.944
# Current Loss on iteration 77 170.94008
# Current Loss on iteration 78 170.93648
# Current Loss on iteration 79 170.93318
# Current Loss on iteration 80 170.93013
# Current Loss on iteration 81 170.9274
# Current Loss on iteration 82 170.92474
# Current Loss on iteration 83 170.92245
# Current Loss on iteration 84 170.92026
# Current Loss on iteration 85 170.9183
# Current Loss on iteration 86 170.91643
# Current Loss on iteration 87 170.91463
# Current Loss on iteration 88 170.91313
# Current Loss on iteration 89 170.9117
# Current Loss on iteration 90 170.91032
# Current Loss on iteration 91 170.90906
# Current Loss on iteration 92 170.90787
# Current Loss on iteration 93 170.90677
# Current Loss on iteration 94 170.90587
# Current Loss on iteration 95 170.90503
# Current Loss on iteration 96 170.90425
# Current Loss on iteration 97 170.90344
# Current Loss on iteration 98 170.90268
# Current Loss on iteration 99 170.902

# %% [markdown]
# ### Get the shapes and values of W and b

# %%
#Check Weights and Bias
print('Weights:\n', w.numpy())
print('Bias:\n',b.numpy())
# Out:
# Weights:
#  [[1.2649974]
#  [1.2692019]
#  [1.251856 ]
#  [1.280261 ]]
# Bias:
#  [2.5332978]

# %% [markdown]
# ### Model Prediction on 1st Examples in Test Dataset

# %%
X_test_z[0]
# Out:
# array([0.5022779 , 0.49966326, 0.4919523 , 0.50600046], dtype=float32)

# %%
X_test_z.shape
# Out:
# (200, 4)

# %%
prediction = prediction(X_test_z[0:1], w,b)

# %%
prediction
# Out:
# <tf.Tensor: id=4709, shape=(1, 1), dtype=float32, numpy=array([[5.066518]], dtype=float32)>

# %%
y_test[0]
# Out:
# 0.4599

# %% [markdown]
# ## Classification using tf.Keras
#
# In this exercise, we will build a Deep Neural Network using tf.Keras. We will use Iris Dataset for this exercise.

# %% [markdown]
# ### Load the given Iris data using pandas (Iris.csv)

# %%
data2=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Iris.csv')

# %% [markdown]
# ### Target set has different categories. So, Label encode them. And convert into one-hot vectors using get_dummies in pandas.

# %%
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
data2['Species']= label_encoder.fit_transform(data2['Species'])

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB

# %% [markdown]
# ### Splitting the data into feature set and target set

# %%
X1= np.array(data2.drop(columns=['Species','Id']))

# %%
y1 = np.array(data2['Species'])

# %%
X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1,test_size=0.2,random_state=2324)

# %%
X1_train_z = scale.fit_transform(X1_train)

# %%
X1_test_z = scale.fit_transform(X1_test)

# %%
y1_train = tf.keras.utils.to_categorical(y1_train, num_classes=3)
y1_test = tf.keras.utils.to_categorical(y1_test, num_classes=3)

# %%
print(y1_train.shape)
print('First 2 examples now are: ', y1_train[0:2])
# Out:
# (120, 3)
# First 2 examples now are:  [[0. 0. 1.]
#  [0. 1. 0.]]

# %%
X1_train_z = X1_train_z.astype('float32')
X1_test_z = X1_test_z.astype('float32')
y1_test = y1_test.astype('float32')
y1_train = y1_train.astype('float32')

# %% [markdown]
# ###  Building Model in tf.keras
#
# Build a Linear Classifier model  <br>
# 1.  Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3<br>
# 2. Apply Softmax on Dense Layer outputs <br>
# 3. Use SGD as Optimizer
# 4. Use categorical_crossentropy as loss function

# %%
X1_test_z.shape
# Out:
# (30, 4)

# %%
#Initialize Sequential model
model = tf.keras.models.Sequential()

# %%
#Normalize the data
model.add(tf.keras.layers.BatchNormalization())

# %%
#Add Dense Layer which provides 10 Outputs after applying softmax
model.add(tf.keras.layers.Dense(3, input_shape=(4,),activation='softmax'))

# %%
#Comile the model
model.compile(optimizer='sgd', loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %% [markdown]
# ### Model Training

# %%
model.fit(X1_train_z, y1_train, 
          validation_data=(X1_test_z, y1_test), 
          epochs=100,
          batch_size=X1_train_z.shape[0])
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/100
# 120/120 [==============================] - 1s 6ms/sample - loss: 1.8849 - accuracy: 0.0083 - val_loss: 1.2125 - val_accuracy: 0.3000
# Epoch 2/100
# 120/120 [==============================] - 0s 118us/sample - loss: 1.8560 - accuracy: 0.0083 - val_loss: 1.2103 - val_accuracy: 0.3000
# Epoch 3/100
# 120/120 [==============================] - 0s 109us/sample - loss: 1.8279 - accuracy: 0.0083 - val_loss: 1.2081 - val_accuracy: 0.3000
# Epoch 4/100
# 120/120 [==============================] - 0s 97us/sample - loss: 1.8005 - accuracy: 0.0083 - val_loss: 1.2059 - val_accuracy: 0.3000
# Epoch 5/100
# 120/120 [==============================] - 0s 97us/sample - loss: 1.7738 - accuracy: 0.0083 - val_loss: 1.2037 - val_accuracy: 0.3000
# Epoch 6/100
# 120/120 [==============================] - 0s 88us/sample - loss: 1.7477 - accuracy: 0.0083 - val_loss: 1.2016 - val_accuracy: 0.3000
# Epoch 7/100
# 120/120 [==============================] - 0s 94us/sample - loss: 1.7223 - accuracy: 0.0083 - val_loss: 1.1995 - val_accuracy: 0.3000
# Epoch 8/100
# 120/120 [==============================] - 0s 107us/sample - loss: 1.6975 - accuracy: 0.0083 - val_loss: 1.1973 - val_accuracy: 0.3000
# Epoch 9/100
# 120/120 [==============================] - 0s 149us/sample - loss: 1.6732 - accuracy: 0.0083 - val_loss: 1.1952 - val_accuracy: 0.3000
# Epoch 10/100
# 120/120 [==============================] - 0s 128us/sample - loss: 1.6496 - accuracy: 0.0083 - val_loss: 1.1931 - val_accuracy: 0.3000
# Epoch 11/100
# 120/120 [==============================] - 0s 112us/sample - loss: 1.6265 - accuracy: 0.0083 - val_loss: 1.1910 - val_accuracy: 0.3000
# Epoch 12/100
# 120/120 [==============================] - 0s 103us/sample - loss: 1.6040 - accuracy: 0.0083 - val_loss: 1.1889 - val_accuracy: 0.3000
# Epoch 13/100
# 120/120 [==============================] - 0s 106us/sample - loss: 1.5821 - accuracy: 0.0083 - val_loss: 1.1869 - val_accuracy: 0.3000
# Epoch 14/100
# 120/120 [==============================] - 0s 168us/sample - loss: 1.5606 - accuracy: 0.0083 - val_loss: 1.1848 - val_accuracy: 0.3000
# Epoch 15/100
# 120/120 [==============================] - 0s 154us/sample - loss: 1.5397 - accuracy: 0.0167 - val_loss: 1.1828 - val_accuracy: 0.3000
# Epoch 16/100
# 120/120 [==============================] - 0s 119us/sample - loss: 1.5192 - accuracy: 0.0167 - val_loss: 1.1808 - val_accuracy: 0.3000
# Epoch 17/100
# 120/120 [==============================] - 0s 118us/sample - loss: 1.4992 - accuracy: 0.0167 - val_loss: 1.1787 - val_accuracy: 0.3000
# Epoch 18/100
# 120/120 [==============================] - 0s 88us/sample - loss: 1.4797 - accuracy: 0.0167 - val_loss: 1.1767 - val_accuracy: 0.3000
# Epoch 19/100
# 120/120 [==============================] - 0s 160us/sample - loss: 1.4607 - accuracy: 0.0167 - val_loss: 1.1747 - val_accuracy: 0.3000
# Epoch 20/100
# 120/120 [==============================] - 0s 154us/sample - loss: 1.4421 - accuracy: 0.0167 - val_loss: 1.1728 - val_accuracy: 0.3000
# Epoch 21/100
# 120/120 [==============================] - 0s 144us/sample - loss: 1.4239 - accuracy: 0.0250 - val_loss: 1.1708 - val_accuracy: 0.3000
# Epoch 22/100
# 120/120 [==============================] - 0s 140us/sample - loss: 1.4062 - accuracy: 0.0333 - val_loss: 1.1688 - val_accuracy: 0.3000
# Epoch 23/100
# 120/120 [==============================] - 0s 97us/sample - loss: 1.3888 - accuracy: 0.0333 - val_loss: 1.1669 - val_accuracy: 0.3000
# Epoch 24/100
# 120/120 [==============================] - 0s 125us/sample - loss: 1.3719 - accuracy: 0.0417 - val_loss: 1.1650 - val_accuracy: 0.3000
# Epoch 25/100
# 120/120 [==============================] - 0s 141us/sample - loss: 1.3554 - accuracy: 0.0583 - val_loss: 1.1631 - val_accuracy: 0.3000
# Epoch 26/100
# 120/120 [==============================] - 0s 141us/sample - loss: 1.3392 - accuracy: 0.0583 - val_loss: 1.1612 - val_accuracy: 0.3000
# Epoch 27/100
# 120/120 [==============================] - 0s 113us/sample - loss: 1.3234 - accuracy: 0.0750 - val_loss: 1.1593 - val_accuracy: 0.3000
# Epoch 28/100
# 120/120 [==============================] - 0s 131us/sample - loss: 1.3080 - accuracy: 0.1083 - val_loss: 1.1574 - val_accuracy: 0.3000
# Epoch 29/100
# 120/120 [==============================] - 0s 94us/sample - loss: 1.2929 - accuracy: 0.1167 - val_loss: 1.1555 - val_accuracy: 0.3000
# Epoch 30/100
# 120/120 [==============================] - 0s 164us/sample - loss: 1.2781 - accuracy: 0.1583 - val_loss: 1.1537 - val_accuracy: 0.3000
# Epoch 31/100
# 120/120 [==============================] - 0s 147us/sample - loss: 1.2637 - accuracy: 0.1917 - val_loss: 1.1519 - val_accuracy: 0.3000
# Epoch 32/100
# 120/120 [==============================] - 0s 146us/sample - loss: 1.2497 - accuracy: 0.2000 - val_loss: 1.1500 - val_accuracy: 0.3000
# Epoch 33/100
# 120/120 [==============================] - 0s 131us/sample - loss: 1.2359 - accuracy: 0.2083 - val_loss: 1.1482 - val_accuracy: 0.3000
# Epoch 34/100
# 120/120 [==============================] - 0s 109us/sample - loss: 1.2225 - accuracy: 0.2417 - val_loss: 1.1464 - val_accuracy: 0.3000
# Epoch 35/100
# 120/120 [==============================] - 0s 130us/sample - loss: 1.2093 - accuracy: 0.2583 - val_loss: 1.1447 - val_accuracy: 0.3000
# Epoch 36/100
# 120/120 [==============================] - 0s 117us/sample - loss: 1.1965 - accuracy: 0.3000 - val_loss: 1.1429 - val_accuracy: 0.3000
# Epoch 37/100
# 120/120 [==============================] - 0s 108us/sample - loss: 1.1839 - accuracy: 0.3000 - val_loss: 1.1411 - val_accuracy: 0.3000
# Epoch 38/100
# 120/120 [==============================] - 0s 149us/sample - loss: 1.1717 - accuracy: 0.3167 - val_loss: 1.1394 - val_accuracy: 0.3000
# Epoch 39/100
# 120/120 [==============================] - 0s 109us/sample - loss: 1.1597 - accuracy: 0.3167 - val_loss: 1.1376 - val_accuracy: 0.3000
# Epoch 40/100
# 120/120 [==============================] - 0s 119us/sample - loss: 1.1479 - accuracy: 0.3250 - val_loss: 1.1359 - val_accuracy: 0.3000
# Epoch 41/100
# 120/120 [==============================] - 0s 112us/sample - loss: 1.1365 - accuracy: 0.3333 - val_loss: 1.1342 - val_accuracy: 0.3000
# Epoch 42/100
# 120/120 [==============================] - 0s 137us/sample - loss: 1.1253 - accuracy: 0.3333 - val_loss: 1.1325 - val_accuracy: 0.3000
# Epoch 43/100
# 120/120 [==============================] - 0s 147us/sample - loss: 1.1143 - accuracy: 0.3833 - val_loss: 1.1308 - val_accuracy: 0.3000
# Epoch 44/100
# 120/120 [==============================] - 0s 146us/sample - loss: 1.1036 - accuracy: 0.4083 - val_loss: 1.1292 - val_accuracy: 0.3000
# Epoch 45/100
# 120/120 [==============================] - 0s 184us/sample - loss: 1.0931 - accuracy: 0.4167 - val_loss: 1.1275 - val_accuracy: 0.3000
# Epoch 46/100
# 120/120 [==============================] - 0s 116us/sample - loss: 1.0829 - accuracy: 0.4250 - val_loss: 1.1259 - val_accuracy: 0.3000
# Epoch 47/100
# 120/120 [==============================] - 0s 113us/sample - loss: 1.0729 - accuracy: 0.4417 - val_loss: 1.1242 - val_accuracy: 0.3000
# Epoch 48/100
# 120/120 [==============================] - 0s 120us/sample - loss: 1.0631 - accuracy: 0.4583 - val_loss: 1.1226 - val_accuracy: 0.3000
# Epoch 49/100
# 120/120 [==============================] - 0s 139us/sample - loss: 1.0535 - accuracy: 0.4583 - val_loss: 1.1210 - val_accuracy: 0.3000
# Epoch 50/100
# 120/120 [==============================] - 0s 136us/sample - loss: 1.0441 - accuracy: 0.4750 - val_loss: 1.1194 - val_accuracy: 0.3000
# Epoch 51/100
# 120/120 [==============================] - 0s 137us/sample - loss: 1.0350 - accuracy: 0.4917 - val_loss: 1.1178 - val_accuracy: 0.3000
# Epoch 52/100
# 120/120 [==============================] - 0s 116us/sample - loss: 1.0260 - accuracy: 0.5167 - val_loss: 1.1162 - val_accuracy: 0.3000
# Epoch 53/100
# 120/120 [==============================] - 0s 147us/sample - loss: 1.0172 - accuracy: 0.5333 - val_loss: 1.1146 - val_accuracy: 0.3000
# Epoch 54/100
# 120/120 [==============================] - 0s 127us/sample - loss: 1.0086 - accuracy: 0.5417 - val_loss: 1.1131 - val_accuracy: 0.3000
# Epoch 55/100
# 120/120 [==============================] - 0s 140us/sample - loss: 1.0003 - accuracy: 0.5667 - val_loss: 1.1115 - val_accuracy: 0.3000
# Epoch 56/100
# 120/120 [==============================] - 0s 109us/sample - loss: 0.9920 - accuracy: 0.5750 - val_loss: 1.1100 - val_accuracy: 0.3000
# Epoch 57/100
# 120/120 [==============================] - 0s 151us/sample - loss: 0.9840 - accuracy: 0.5833 - val_loss: 1.1085 - val_accuracy: 0.3000
# Epoch 58/100
# 120/120 [==============================] - 0s 119us/sample - loss: 0.9761 - accuracy: 0.5917 - val_loss: 1.1069 - val_accuracy: 0.3000
# Epoch 59/100
# 120/120 [==============================] - 0s 143us/sample - loss: 0.9684 - accuracy: 0.5833 - val_loss: 1.1054 - val_accuracy: 0.3000
# Epoch 60/100
# 120/120 [==============================] - 0s 148us/sample - loss: 0.9609 - accuracy: 0.5917 - val_loss: 1.1039 - val_accuracy: 0.3000
# Epoch 61/100
# 120/120 [==============================] - 0s 147us/sample - loss: 0.9535 - accuracy: 0.6000 - val_loss: 1.1024 - val_accuracy: 0.3000
# Epoch 62/100
# 120/120 [==============================] - 0s 120us/sample - loss: 0.9463 - accuracy: 0.6000 - val_loss: 1.1010 - val_accuracy: 0.3000
# Epoch 63/100
# 120/120 [==============================] - 0s 125us/sample - loss: 0.9393 - accuracy: 0.6083 - val_loss: 1.0995 - val_accuracy: 0.3000
# Epoch 64/100
# 120/120 [==============================] - 0s 142us/sample - loss: 0.9323 - accuracy: 0.6167 - val_loss: 1.0980 - val_accuracy: 0.3000
# Epoch 65/100
# 120/120 [==============================] - 0s 104us/sample - loss: 0.9256 - accuracy: 0.6500 - val_loss: 1.0966 - val_accuracy: 0.3000
# Epoch 66/100
# 120/120 [==============================] - 0s 134us/sample - loss: 0.9189 - accuracy: 0.6667 - val_loss: 1.0951 - val_accuracy: 0.3000
# Epoch 67/100
# 120/120 [==============================] - 0s 129us/sample - loss: 0.9124 - accuracy: 0.6667 - val_loss: 1.0937 - val_accuracy: 0.3000
# Epoch 68/100
# 120/120 [==============================] - 0s 132us/sample - loss: 0.9061 - accuracy: 0.6667 - val_loss: 1.0923 - val_accuracy: 0.3000
# Epoch 69/100
# 120/120 [==============================] - 0s 177us/sample - loss: 0.8998 - accuracy: 0.6750 - val_loss: 1.0908 - val_accuracy: 0.3000
# Epoch 70/100
# 120/120 [==============================] - 0s 140us/sample - loss: 0.8937 - accuracy: 0.6750 - val_loss: 1.0894 - val_accuracy: 0.3000
# Epoch 71/100
# 120/120 [==============================] - 0s 138us/sample - loss: 0.8878 - accuracy: 0.6750 - val_loss: 1.0880 - val_accuracy: 0.3000
# Epoch 72/100
# 120/120 [==============================] - 0s 96us/sample - loss: 0.8819 - accuracy: 0.6917 - val_loss: 1.0866 - val_accuracy: 0.3000
# Epoch 73/100
# 120/120 [==============================] - 0s 125us/sample - loss: 0.8762 - accuracy: 0.6917 - val_loss: 1.0852 - val_accuracy: 0.3000
# Epoch 74/100
# 120/120 [==============================] - 0s 126us/sample - loss: 0.8705 - accuracy: 0.6917 - val_loss: 1.0838 - val_accuracy: 0.3000
# Epoch 75/100
# 120/120 [==============================] - 0s 127us/sample - loss: 0.8650 - accuracy: 0.6917 - val_loss: 1.0824 - val_accuracy: 0.3000
# Epoch 76/100
# 120/120 [==============================] - 0s 138us/sample - loss: 0.8596 - accuracy: 0.6917 - val_loss: 1.0811 - val_accuracy: 0.3000
# Epoch 77/100
# 120/120 [==============================] - 0s 88us/sample - loss: 0.8543 - accuracy: 0.6917 - val_loss: 1.0797 - val_accuracy: 0.3000
# Epoch 78/100
# 120/120 [==============================] - 0s 126us/sample - loss: 0.8491 - accuracy: 0.6917 - val_loss: 1.0783 - val_accuracy: 0.3000
# Epoch 79/100
# 120/120 [==============================] - 0s 127us/sample - loss: 0.8440 - accuracy: 0.6917 - val_loss: 1.0770 - val_accuracy: 0.3000
# Epoch 80/100
# 120/120 [==============================] - 0s 153us/sample - loss: 0.8390 - accuracy: 0.6917 - val_loss: 1.0756 - val_accuracy: 0.3000
# Epoch 81/100
# 120/120 [==============================] - 0s 131us/sample - loss: 0.8341 - accuracy: 0.6917 - val_loss: 1.0743 - val_accuracy: 0.3000
# Epoch 82/100
# 120/120 [==============================] - 0s 111us/sample - loss: 0.8293 - accuracy: 0.6917 - val_loss: 1.0729 - val_accuracy: 0.3000
# Epoch 83/100
# 120/120 [==============================] - 0s 126us/sample - loss: 0.8246 - accuracy: 0.6917 - val_loss: 1.0716 - val_accuracy: 0.3000
# Epoch 84/100
# 120/120 [==============================] - 0s 135us/sample - loss: 0.8199 - accuracy: 0.6917 - val_loss: 1.0703 - val_accuracy: 0.3000
# Epoch 85/100
# 120/120 [==============================] - 0s 128us/sample - loss: 0.8154 - accuracy: 0.6917 - val_loss: 1.0689 - val_accuracy: 0.3000
# Epoch 86/100
# 120/120 [==============================] - 0s 145us/sample - loss: 0.8109 - accuracy: 0.6917 - val_loss: 1.0676 - val_accuracy: 0.3000
# Epoch 87/100
# 120/120 [==============================] - 0s 130us/sample - loss: 0.8066 - accuracy: 0.6917 - val_loss: 1.0663 - val_accuracy: 0.3000
# Epoch 88/100
# 120/120 [==============================] - 0s 141us/sample - loss: 0.8023 - accuracy: 0.6917 - val_loss: 1.0650 - val_accuracy: 0.3000
# Epoch 89/100
# 120/120 [==============================] - 0s 128us/sample - loss: 0.7981 - accuracy: 0.6917 - val_loss: 1.0637 - val_accuracy: 0.3000
# Epoch 90/100
# 120/120 [==============================] - 0s 189us/sample - loss: 0.7939 - accuracy: 0.7000 - val_loss: 1.0624 - val_accuracy: 0.3000
# Epoch 91/100
# 120/120 [==============================] - 0s 140us/sample - loss: 0.7898 - accuracy: 0.7000 - val_loss: 1.0611 - val_accuracy: 0.3000
# Epoch 92/100
# 120/120 [==============================] - 0s 164us/sample - loss: 0.7858 - accuracy: 0.6917 - val_loss: 1.0598 - val_accuracy: 0.3000
# Epoch 93/100
# 120/120 [==============================] - 0s 116us/sample - loss: 0.7819 - accuracy: 0.6917 - val_loss: 1.0585 - val_accuracy: 0.3000
# Epoch 94/100
# 120/120 [==============================] - 0s 127us/sample - loss: 0.7781 - accuracy: 0.6833 - val_loss: 1.0572 - val_accuracy: 0.3000
# Epoch 95/100
# 120/120 [==============================] - 0s 108us/sample - loss: 0.7743 - accuracy: 0.6833 - val_loss: 1.0559 - val_accuracy: 0.3000
# Epoch 96/100
# 120/120 [==============================] - 0s 132us/sample - loss: 0.7706 - accuracy: 0.6750 - val_loss: 1.0546 - val_accuracy: 0.3000
# Epoch 97/100
# 120/120 [==============================] - 0s 124us/sample - loss: 0.7669 - accuracy: 0.6750 - val_loss: 1.0533 - val_accuracy: 0.3000
# Epoch 98/100
# 120/120 [==============================] - 0s 160us/sample - loss: 0.7633 - accuracy: 0.6750 - val_loss: 1.0521 - val_accuracy: 0.3000
# Epoch 99/100
# 120/120 [==============================] - 0s 145us/sample - loss: 0.7598 - accuracy: 0.6750 - val_loss: 1.0508 - val_accuracy: 0.3000
# Epoch 100/100
# 120/120 [==============================] - 0s 122us/sample - loss: 0.7563 - accuracy: 0.6750 - val_loss: 1.0495 - val_accuracy: 0.3000

# %% [markdown]
# ### Model Prediction

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo multiple                  16
# _________________________________________________________________
# dense (Dense)                multiple                  15
# =================================================================
# Total params: 31
# Trainable params: 23
# Non-trainable params: 8
# _________________________________________________________________

# %% [markdown]
# ### Save the Model

# %%
model.save('mnist_lc.h5')

# %% [markdown]
# ### Build and Train a Deep Neural network with 2 hidden layer  - Optional - For Practice
#
# Does it perform better than Linear Classifier? What could be the reason for difference in performance?
