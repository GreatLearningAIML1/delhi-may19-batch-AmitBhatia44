# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
# !pip3 install -U tensorflow --quiet

# %%
import tensorflow as tf

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
#Initialize Sequential model
model = tf.keras.models.Sequential()

#Reshape data from 2D to 1D -> 28x28 to 784
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))

#Normalize the data
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Add 1st hidden layer
model.add(tf.keras.layers.Dense(200, activation='relu'))

# Dropout
model.add(tf.keras.layers.Dropout(0.25))

#Normalize the hidden layer
model.add(tf.keras.layers.BatchNormalization())

# %%
#Add 2nd hidden layer
model.add(tf.keras.layers.Dense(100, activation='relu'))

# Dropout
model.add(tf.keras.layers.Dropout(0.25))

#Normalize the hidden layer
model.add(tf.keras.layers.BatchNormalization())

# %%
#Add OUTPUT layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %% [markdown]
# ## Build the Graph...

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %% [markdown]
# ## Review model

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_9 (Reshape)          (None, 784)               0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 784)               3136
# _________________________________________________________________
# dense_18 (Dense)             (None, 200)               157000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 200)               0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 200)               800
# _________________________________________________________________
# dense_19 (Dense)             (None, 100)               20100
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 100)               0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 100)               400
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 182,446
# Trainable params: 180,278
# Non-trainable params: 2,168
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
model.fit(x_train,y_train,          
          validation_data=(x_test,y_test),
          epochs=15,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 14s 225us/sample - loss: 0.5786 - acc: 0.7970 - val_loss: 0.4089 - val_acc: 0.8494
# Epoch 2/15
# 60000/60000 [==============================] - 13s 219us/sample - loss: 0.4441 - acc: 0.8388 - val_loss: 0.3820 - val_acc: 0.8605
# Epoch 3/15
# 60000/60000 [==============================] - 13s 219us/sample - loss: 0.4074 - acc: 0.8522 - val_loss: 0.3661 - val_acc: 0.8717
# Epoch 4/15
# 60000/60000 [==============================] - 13s 218us/sample - loss: 0.3884 - acc: 0.8584 - val_loss: 0.3636 - val_acc: 0.8715
# Epoch 5/15
# 60000/60000 [==============================] - 13s 217us/sample - loss: 0.3679 - acc: 0.8655 - val_loss: 0.3399 - val_acc: 0.8762
# Epoch 6/15
# 60000/60000 [==============================] - 13s 221us/sample - loss: 0.3573 - acc: 0.8693 - val_loss: 0.3597 - val_acc: 0.8761
# Epoch 7/15
# 60000/60000 [==============================] - 13s 217us/sample - loss: 0.3460 - acc: 0.8735 - val_loss: 0.3551 - val_acc: 0.8733
# Epoch 8/15
# 60000/60000 [==============================] - 13s 224us/sample - loss: 0.3408 - acc: 0.8757 - val_loss: 0.3499 - val_acc: 0.8788
# Epoch 9/15
# 60000/60000 [==============================] - 13s 218us/sample - loss: 0.3313 - acc: 0.8776 - val_loss: 0.3346 - val_acc: 0.8843
# Epoch 10/15
# 60000/60000 [==============================] - 13s 215us/sample - loss: 0.3247 - acc: 0.8791 - val_loss: 0.3352 - val_acc: 0.8824
# Epoch 11/15
# 60000/60000 [==============================] - 13s 222us/sample - loss: 0.3186 - acc: 0.8831 - val_loss: 0.3351 - val_acc: 0.8867
# Epoch 12/15
# 60000/60000 [==============================] - 13s 223us/sample - loss: 0.3159 - acc: 0.8832 - val_loss: 0.3249 - val_acc: 0.8849
# Epoch 13/15
# 60000/60000 [==============================] - 13s 223us/sample - loss: 0.3090 - acc: 0.8862 - val_loss: 0.3444 - val_acc: 0.8848
# Epoch 14/15
# 60000/60000 [==============================] - 14s 229us/sample - loss: 0.3019 - acc: 0.8885 - val_loss: 0.3529 - val_acc: 0.8866
# Epoch 15/15
# 60000/60000 [==============================] - 14s 225us/sample - loss: 0.3024 - acc: 0.8884 - val_loss: 0.3440 - val_acc: 0.8848

# %%
loss_and_metrics = model.evaluate(x_test, y_test)
print(loss_and_metrics)
# Out:
# 10000/10000 [==============================] - 1s 80us/sample - loss: 0.3440 - acc: 0.8848
# [0.34397447867393494, 0.8848]
